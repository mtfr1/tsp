# %%
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt

from tsp import *

# %%
points = gen_points(10)

# %%
G = create_graph(points, euclid_dist)
branch_and_bound(G)
# Out:
# ([0, 9, 8, 7, 6, 5, 4, 3, 2, 1, 0], 304)

# %% [markdown]
# ## Análise

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
df = pd.read_csv("data.csv")
df["time"] = df["time"].apply(lambda x: x * 60)

df
# Out:
#                  tsp_func  num_verts  length        time      memory  \
# 0   Twice around the tree         16     420    0.001436  151.480469
# 1   Twice around the tree         16     596    0.000956  151.488281
# 2            Christofides         16     402    0.010854  151.625000
# 3            Christofides         16     490    0.004140  151.644531
# 4   Twice around the tree         32     666    0.001865  151.914062
# 5   Twice around the tree         32     862    0.001874  151.937500
# 6            Christofides         32     551    0.017846  152.031250
# 7            Christofides         32     708    0.014694  152.046875
# 8   Twice around the tree         64     790    0.006562  153.167969
# 9   Twice around the tree         64    1080    0.007026  153.398438
# 10           Christofides         64     670    0.066504  153.652344
# 11           Christofides         64     898    0.050637  153.652344
# 12  Twice around the tree        128    1146    0.026390  158.027344
# 13  Twice around the tree        128    1578    0.064368  157.902344
# 14           Christofides        128     976    0.363532  159.035156
# 15           Christofides        128    1230    0.398925  158.546875
# 16  Twice around the tree        256    1594    0.150391  177.054688
# 17  Twice around the tree        256    2050    0.128226  176.757812
# 18           Christofides        256    1290    1.593635  179.851562
# 19           Christofides        256    1734    2.194375  177.074219
# 20  Twice around the tree        512    2237    0.566284  257.847656
# 21  Twice around the tree        512    2968    0.636708  257.199219
# 22           Christofides        512    1815    9.434845  260.250000
# 23           Christofides        512    2444   11.638930  256.328125
# 24  Twice around the tree       1024    3005    2.636663  586.066406
# 25  Twice around the tree       1024    4024    3.042949  580.234375
# 26           Christofides       1024    2422   72.180937  598.406250
# 27           Christofides       1024    3338  104.205790  572.578125
#
#     dist_type
# 0    Euclides
# 1   Manhattan
# 2    Euclides
# 3   Manhattan
# 4    Euclides
# 5   Manhattan
# 6    Euclides
# 7   Manhattan
# 8    Euclides
# 9   Manhattan
# 10   Euclides
# 11  Manhattan
# 12   Euclides
# 13  Manhattan
# 14   Euclides
# 15  Manhattan
# 16   Euclides
# 17  Manhattan
# 18   Euclides
# 19  Manhattan
# 20   Euclides
# 21  Manhattan
# 22   Euclides
# 23  Manhattan
# 24   Euclides
# 25  Manhattan
# 26   Euclides
# 27  Manhattan

# %%
# O algoritmo de Christofides, por ser cúbico, gasta um tempo substancialmente maior do que o Twice Around the Tree,
# que é da ordem de O(n log n). Observando a escala y, é possível perceber que a distância de Manhattan é um pouco
# mais lenta, talvez aumentando o número de vértices essa diferença fique mais aparente.

euclid = df[df["dist_type"] == "Euclides"]
euclid = euclid.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "time" : "Tempo (s)"})
plt.figure(figsize=(13,5))

plt.subplot(1, 2, 1)
plt.title("N.º de vértices x Tempo (s), distância de Euclides")
sns.lineplot(x="Número de vértices", y="Tempo (s)", hue="Algoritmo", data=euclid)

plt.subplot(1, 2, 2)
manh = df[df["dist_type"] == "Manhattan"]
manh = manh.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "time" : "Tempo (s)"})
plt.title("N.º de vértices x Tempo (s), distância de Manhattan")
sns.lineplot(x="Número de vértices", y="Tempo (s)", hue="Algoritmo", data=manh)

plt.tight_layout()
plt.show()

# %%
#### AUMENTAR O NUMERO DE VERTICES PARA O UPPERBOUND

# %%
# Os dois algoritmos e as duas distâncias crescem na mesma "velocidade" se tratando de memória.

euclid_m = df[df["dist_type"] == "Euclides"]
euclid_m = euclid.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "memory" : "Memória (Mb)"})
plt.figure(figsize=(13,5))

plt.subplot(1, 2, 1)
plt.title("N.º de vértices x Memória (Mb), distância de Euclides")
sns.lineplot(x="Número de vértices", y="Memória (Mb)", hue="Algoritmo", data=euclid_m)

plt.subplot(1, 2, 2)
manh_m = df[df["dist_type"] == "Manhattan"]
manh_m = manh.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "memory" : "Memória (Mb)"})
plt.title("N.º de vértices x Memória (Mb), distância de Manhattan")
sns.lineplot(x="Número de vértices", y="Memória (Mb)", hue="Algoritmo", data=manh_m)

plt.tight_layout()
plt.show()

# %%
df_bb = pd.read_csv("data_full.csv")

# %%
df_bb["time"] = df_bb["time"].apply(lambda x: x * 60)

# %%
df_bb = df_bb.drop(df_bb.index[[54, 55, 56, 57]])

# %%
bb_euclid = df_bb[df_bb["dist_type"] == "Euclides"]
bb_euclid = bb_euclid.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "solution" : "Solução"})
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.title("N.º de vértices x Solução, distância de Euclides")
sns.barplot(x="Número de vértices", y="Solução", hue="Algoritmo", data=bb_euclid)

plt.subplot(1, 2, 2)
bb_manh = df_bb[df_bb["dist_type"] == "Manhattan"]
bb_manh = bb_manh.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "solution" : "Solução"})
bb_manh
plt.title("N.º de vértices x Solução, distância de Manhattan")
sns.barplot(x="Número de vértices", y="Solução", hue="Algoritmo", data=bb_manh)

plt.tight_layout()
plt.show()

# %%
bb_euclid = df_bb[df_bb["dist_type"] == "Euclides"]
bb_euclid = bb_euclid[bb_euclid["tsp_func"] == "Branch and Bound"]
bb_euclid = bb_euclid.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "time" : "Tempo (s)"})
plt.figure(figsize=(13,5))

plt.subplot(1, 2, 1)
plt.title("N.º de vértices x Solução, distância de Euclides")
sns.lineplot(x="Número de vértices", y="Tempo (s)", hue="Algoritmo", data=bb_euclid)

plt.subplot(1, 2, 2)
bb_manh = df_bb[df_bb["dist_type"] == "Manhattan"]
bb_manh = bb_manh[bb_manh["tsp_func"] == "Branch and Bound"]
bb_manh = bb_manh.rename(columns={"tsp_func": "Algoritmo", "num_verts": "Número de vértices", "time" : "Tempo (s)"})
bb_manh
plt.title("N.º de vértices x Solução, distância de Manhattan")
sns.lineplot(x="Número de vértices", y="Tempo (s)", hue="Algoritmo", data=bb_manh)

plt.tight_layout()
plt.show()

# %%
# Como se pode concluir das análises, existe um trade-off na escolha dos três algoritmos. O Branch-and-bound retorna
# solução exata, porém se torna inviável com um pequeno número de vértices. Já o Christofides apresenta um coeficiente
# de aproximação razoável (alpha = 1.5), porém possui um alto custo assintótico, se tornando, também, inviável para
# problemas grandes. Por fim, o Twice-around-the-tree é o mais rápido dentre os algoritmos vistos mas apresenta
# a maior diferença da solução ótima.

# %%
df_2 = pd.read_csv("euclidxmanh.csv")
df_2["time"] = df_2["time"].apply(lambda x: x * 60)

# %%
# A distância de Manhattan aparenta ser um pouco mais lenta do que a distância de Euclides

df_2 = df_2.rename(columns={"dist_type": "Distância", "num_verts": "Número de vértices", "time" : "Tempo (s)"})
plt.figure(figsize=(13,5))
plt.title("N.º de vértices x Tempo (s)")
sns.lineplot(x="Número de vértices", y="Tempo (s)", hue="Distância", data=df_2)
plt.show()
